# %%
# pyvista for interactive plotting
# https://jsdokken.com/FEniCS-workshop/src/outputting.html

# %%
import os, sys, pyvista

# %%
if sys.platform == "linux" and (os.getenv("CI") or pyvista.OFF_SCREEN):
    pyvista.start_xvfb(0.05)

# %%
plotter = pyvista.Plotter()
plotter.show()
plotter.screenshot("test.png")
# Out:
# /dolfinx-env/lib/python3.12/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# error: XDG_RUNTIME_DIR is invalid or not set in the environment.
# MESA: error: ZINK: failed to choose pdev
# glx: failed to create drisw screen
# <PIL.Image.Image image mode=RGB size=1024x768>
# pyvista_ndarray([[[255, 255, 255],
#                   [255, 255, 255],
#                   [255, 255, 255],
#                   ...,
#                   [255, 255, 255],
#                   [255, 255, 255],
#                   [255, 255, 255]],
#
#                  [[255, 255, 255],
#                   [255, 255, 255],
#                   [255, 255, 255],
#                   ...,
#                   [255, 255, 255],
#                   [255, 255, 255],
#                   [255, 255, 255]],
#
#                  [[255, 255, 255],
#                   [255, 255, 255],
# ...

# %%
# xdmffile
# vtxwriter - ADIOS2 backend
# FidesWriter
# VTKFile

# %%
# Checkpointing
# ADIOS4DOLFINx
